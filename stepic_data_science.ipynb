# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_performance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
students_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
students_performance.tail(1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 999                    none          77             86             86

# %%
students_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
students_performance.shape
# Out:
# (1000, 8)

# %%
students_performance.groupby('gender').aggregate({'writing score': 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
students_performance.size
# Out:
# 8000

# %%
students_performance.iloc[0:5, 0:2]
# Out:
#    gender race/ethnicity
# 0  female        group B
# 1  female        group C
# 2  female        group B
# 3    male        group A
# 4    male        group C

# %%
students_performance.iloc[[1, 2], [0, 2]]
# Out:
#    gender parental level of education
# 1  female                some college
# 2  female             master's degree

# %%
students_performance['gender'][:5]
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
students_performance.get_dtype_counts()
# Out:
# int64     3
# object    5
# dtype: int64

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')
df.shape
df.get_dtype_counts()
# Out:
# float64    2
# int64      5
# object     5
# dtype: int64

# %%
students_performance.gender[:5]
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
students_performance.loc[(students_performance.gender == 'female')&(students_performance['writing score'] > 70), ['writing score']][:5]
# Out:
#    writing score
# 0             74
# 1             88
# 2             93
# 5             78
# 6             92

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
print((df['lunch']=='free/reduced').mean())
print(len(df[df['lunch']=='free/reduced'])/len(df))
print((df['lunch']=='free/reduced').value_counts(normalize=True))
# Out:
# 0.355
# 0.355
# False    0.645
# True     0.355
# Name: lunch, dtype: float64

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
df['full_score'] = df['writing score'] + df['reading score'] + df['math score']
df.groupby('lunch').agg(['mean', 'var'])
# Out:
#              math score             reading score             writing score  \
#                    mean         var          mean         var          mean
# lunch
# free/reduced  58.921127  229.824270     64.653521  221.871139     63.022535
# standard      70.034109  186.418089     71.654264  191.285560     70.823256
#
#                           full_score
#                      var        mean          var
# lunch
# free/reduced  238.202881  186.597183  1881.388128
# standard      205.620887  212.511628  1564.955222

# %%
students_performance.rename(columns={'math score': 'math_score'})
students_performance.columns=students_performance.columns.str.replace(' ','_')
students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
writing_score_query = 70
students_performance.query(f"gender == 'female' & writing_score > {writing_score_query}")[:5]
# Out:
#    gender race/ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
students_performance['parental_level_of_education'].isin(["bachelor's degree", "master's degree"])[:5]
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# Name: parental_level_of_education, dtype: bool

# %%
students_performance[students_performance['parental_level_of_education'].isin(["bachelor's degree", "master's degree"])][:5]
# Out:
#     gender race/ethnicity parental_level_of_education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 2   female        group B             master's degree      standard
# 14  female        group A             master's degree      standard
# 18    male        group C             master's degree  free/reduced
# 24    male        group D           bachelor's degree  free/reduced
#
#    test_preparation_course  math_score  reading_score  writing_score
# 0                     none          72             72             74
# 2                     none          90             95             93
# 14                    none          50             53             58
# 18               completed          46             42             46
# 24               completed          74             71             80

# %%
query_list = ["bachelor's degree", "master's degree"]
students_performance.query("parental_level_of_education == @query_list")[:5]
# Out:
#     gender race/ethnicity parental_level_of_education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 2   female        group B             master's degree      standard
# 14  female        group A             master's degree      standard
# 18    male        group C             master's degree  free/reduced
# 24    male        group D           bachelor's degree  free/reduced
#
#    test_preparation_course  math_score  reading_score  writing_score
# 0                     none          72             72             74
# 2                     none          90             95             93
# 14                    none          50             53             58
# 18               completed          46             42             46
# 24               completed          74             71             80

# %%
mean_scores = students_performance.groupby(['gender', 'race/ethnicity'], as_index=False) \
    .agg({'math_score': 'mean', 'reading_score': 'mean'}) \
    .rename(columns = {'math_score': 'mean_math_score', 'reading_score': 'mean_reading_score'})
mean_scores
# Out:
#    gender race/ethnicity  mean_math_score  meanreading_score
# 0  female        group A        58.527778          69.000000
# 1  female        group B        61.403846          71.076923
# 2  female        group C        62.033333          71.944444
# 3  female        group D        65.248062          74.046512
# 4  female        group E        70.811594          75.840580
# 5    male        group A        63.735849          61.735849
# 6    male        group B        65.930233          62.848837
# 7    male        group C        67.611511          65.424460
# 8    male        group D        69.413534          66.135338
# 9    male        group E        76.746479          70.295775

# %%
students_performance.groupby(['gender', 'race/ethnicity']).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %%
students_performance.sort_values(['gender', 'math_score'], ascending=False).groupby('gender').head()
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 149               completed         100            100             93
# ...

# %%
students_performance['total_score'] = students_performance['writing_score'] + students_performance['reading_score'] + students_performance['math_score']

# %%
students_performance.assign(total_score_log=np.log(students_performance.total_score))[:5]
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  total_score_log
# 0          218         5.384495
# 1          247         5.509388
# 2          278         5.627621
# ...

# %%
students_performance.drop(['total_score'], axis=1)[:5]
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')
df[['id', 'legs']].groupby('legs', as_index=False).count()
# Out:
#    legs  id
# 0     0  11
# 1     2  95
# 2     4   7
# 3     6   3
# 4     8   1

# %%
df.groupby('legs').legs.count()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %%
df['legs'].value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv', index_col=0)
df.groupby(['Type', 'Executor']).describe()
# Out:
#               Salary                                                       \
#                count        mean        std    min     25%    50%     75%
# Type Executor
# A    Loopa       1.0   58.000000        NaN   58.0   58.00   58.0   58.00
#      Pupa        6.0  160.833333  67.008706   55.0  125.75  172.0  209.25
# B    Loopa       6.0  145.166667  76.851589   50.0   83.75  156.5  188.75
#      Pupa        1.0   77.000000        NaN   77.0   77.00   77.0   77.00
# C    Loopa       6.0  154.333333  76.810590   54.0   97.00  160.0  210.25
#      Pupa        2.0   74.500000  27.577164   55.0   64.75   74.5   84.25
# D    Loopa       7.0  137.714286  35.761778   78.0  119.00  146.0  160.50
#      Pupa        4.0  146.500000  59.769000   63.0  123.75  164.5  187.25
# E    Loopa       6.0  164.000000  54.680892   83.0  130.50  170.0  210.25
#      Pupa        5.0  131.200000  60.334070   65.0   92.00  109.0  193.00
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://stepik.org/media/attachments/course/4852/accountancy.csv", index_col=0)
sub_df=df.groupby(['Type','Executor']).Salary.mean().unstack()
sub_df['Max'] = np.where(sub_df.Loopa > sub_df.Pupa, 'Loopa', 'Pupa')
sub_df
# Out:
# Executor       Loopa        Pupa    Max
# Type
# A          58.000000  160.833333   Pupa
# B         145.166667   77.000000  Loopa
# C         154.333333   74.500000  Loopa
# D         137.714286  146.500000   Pupa
# E         164.000000  131.200000  Loopa
# F         238.000000  136.250000  Loopa

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0)
df.groupby(['attack_type', 'primary_attr']).aggregate('count').sort_values('id', ascending=False).head(1)
# Out:
#                           id  legs  localized_name  name  roles
# attack_type primary_attr
# Ranged      int           40    40              40    40     40

# %%
df[['attack_type', 'primary_attr']].describe().loc['top']
# Out:
# attack_type     Ranged
# primary_attr       int
# Name: top, dtype: object

# %%
df.groupby(['attack_type', 'primary_attr'])['primary_attr'].count().idxmax()
# Out:
# ('Ranged', 'int')

# %%
table=pd.pivot_table(df, index="attack_type", columns="primary_attr", aggfunc="size")
table
# Out:
# primary_attr  agi  int  str
# attack_type
# Melee          19    2   35
# Ranged         18   40    3

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/algae.csv')
df
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
df.groupby('genus').mean()
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/algae.csv')
df = df[df['genus'] == 'Fucus']
df.describe()['alanin']
# Out:
# count    3.000000
# mean     3.566411
# std      3.149943
# min      0.346431
# 25%      2.028965
# 50%      3.711498
# 75%      5.176401
# max      6.641303
# Name: alanin, dtype: float64

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/algae.csv')
df.groupby('genus').aggregate({'alanin': ['min', 'mean', 'max']}).loc[['Fucus']]
# Out:
#          alanin
#             min      mean       max
# genus
# Fucus  0.346431  3.566411  6.641303

# %%
'{min} {mean} {max}'.format(
    **df.loc[df.genus == 'Fucus', 'alanin'] \
        .agg(['min', 'mean', 'max']) \
        .round(2)
)
# Out:
# '0.35 3.57 6.64'

# %%
df = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')
df.groupby('group').count()
df.groupby('group').var()
# Out:
#         sucrose    alanin   citrate   glucose  oleic_acid
# group
# brown  5.459098  7.220351  5.468942  1.767756    4.385233
# green  2.672626  7.059917  3.950113  0.266265    0.540388
# red         NaN       NaN       NaN       NaN         NaN

# %%
df.groupby('group').agg(['count', 'var', np.ptp])
# Out:
#       sucrose                     alanin                     citrate  \
#         count       var       ptp  count       var       ptp   count
# group
# brown       6  5.459098  5.189345      6  7.220351  6.294872       6
# green       3  2.672626  3.259662      3  7.059917  5.232574       3
# red         1       NaN  0.000000      1       NaN  0.000000       1
#
#                           glucose                     oleic_acid            \
#             var       ptp   count       var       ptp      count       var
# group
# brown  5.468942  5.351686       6  1.767756  3.740495          6  4.385233
# green  3.950113  3.857763       3  0.266265  1.026753          3  0.540388
# red         NaN  0.000000       1       NaN  0.000000          1       NaN
#
#
#             ptp
# group
# brown  6.100592
# green  1.396502
# red    0.000000

# %%
df.groupby('group') \
    .agg({'citrate': 'var', 'sucrose': lambda x: x.max() - x.min(), 'glucose': 'count'}) \
    .round(2)
# Out:
#        citrate  sucrose  glucose
# group
# brown     5.47     5.19        6
# green     3.95     3.26        3
# red        NaN     0.00        1

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)
g = sns.heatmap(df, cmap='viridis')
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0)
df['cnt'] = df.roles.str.strip('[]').str.split(',').str.len()
df.cnt.value_counts()
df.cnt.hist()

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)
for column in df.drop('species', axis=1):
    sns.kdeplot(df[column], shade=True)

# %%
d = {'type': ["A", "A", "B", "B"], 'value': [10, 14, 12, 23]}
my_data = pd.DataFrame(data=d)
my_data
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
my_stat.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 4   0  10.0  B -1.0

# %%
subset_1 = my_stat.iloc[:10, [0, 2]]
subset_1
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
exclude = my_stat.index.isin([0,4])
subset_2 = my_stat[~exclude].iloc[:10, [1, 3]]
subset_2
# Out:
#       V2   V4
# 1    7.0  1.0
# 2   11.0  0.0
# 3   11.0  2.0
# 5   11.0  0.0
# 6    9.0  2.0
# 7    9.0  1.0
# 8    9.0  2.0
# 9   10.0  0.0
# 10  10.0  1.0
# 11  10.0  1.0

# %%
subset_2=my_stat.iloc[~my_stat.index.isin([0,4 ]),[1,3]]

subset_3 = my_stat.iloc[(my_stat.index != 0) & (my_stat.index != 4) & (my_stat.index < 10), [1, 3]]
subset_3
# Out:
#      V2   V4
# 1   7.0  1.0
# 2  11.0  0.0
# 3  11.0  2.0
# 5  11.0  0.0
# 6   9.0  2.0
# 7   9.0  1.0
# 8   9.0  2.0
# 9  10.0  0.0

# %%
subset_1 = my_stat[(my_stat.V1 > 0) & (my_stat.V3 == 'A')]
subset_1.head()
# Out:
#     V1    V2 V3   V4
# 3    2  11.0  A  2.0
# 5    2  11.0  A  0.0
# 7    1   9.0  A  1.0
# 10   1  10.0  A  1.0
# 13   1  12.0  A  3.0

# %%
subset_2 = my_stat[(my_stat.V2 != 10) | (my_stat.V4 >= 1)]
subset_2.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 5   2  11.0  A  0.0
